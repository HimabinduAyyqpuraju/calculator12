# %% [markdown]
# <a href="https://colab.research.google.com/github/HimabinduAyyqpuraju/calculator12/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ds = pd.read_csv('/content/drive/MyDrive/Credit_Card_Applications.csv')

# %%
ds
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6  ...  A9  A10  A11  A12  A13  \
# 0      15776156   1  22.08  11.460   2   4   4  ...   0    0    1    2  100
# 1      15739548   0  22.67   7.000   2   8   4  ...   0    0    0    2  160
# 2      15662854   0  29.58   1.750   1   4   4  ...   0    0    1    2  280
# 3      15687688   0  21.67  11.500   1   5   3  ...   1   11    1    2    0
# 4      15715750   1  20.17   8.170   2   6   4  ...   1   14    0    2   60
# ..          ...  ..    ...     ...  ..  ..  ..  ...  ..  ...  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  ...   0    0    0    2    0
# 686    15769980   1  20.67   0.415   2   8   4  ...   0    0    0    2    0
# 687    15675450   0  18.83   9.540   2   6   4  ...   0    0    0    2  100
# 688    15776494   0  27.42  14.500   2  14   8  ...   1    1    0    2  120
# 689    15592412   1  41.00   0.040   2  10   4  ...   1    1    0    1  560
#
#       A14  Class
# 0    1213      0
# 1       1      0
# 2       1      0
# 3       1      1
# 4     159      1
# ..    ...    ...
# 685     1      1
# 686    45      0
# 687     1      1
# 688    12      1
# 689     1      1
#
# [690 rows x 16 columns]

# %%
# Give the information related to the Dataframe
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  690 non-null    int64
#  1   A1          690 non-null    int64
#  2   A2          690 non-null    float64
#  3   A3          690 non-null    float64
#  4   A4          690 non-null    int64
#  5   A5          690 non-null    int64
#  6   A6          690 non-null    int64
#  7   A7          690 non-null    float64
#  8   A8          690 non-null    int64
#  9   A9          690 non-null    int64
#  10  A10         690 non-null    int64
#  11  A11         690 non-null    int64
#  12  A12         690 non-null    int64
#  13  A13         690 non-null    int64
#  14  A14         690 non-null    int64
#  15  Class       690 non-null    int64
# dtypes: float64(3), int64(13)
# memory usage: 86.4 KB

# %%
import random
age = []
height = []
weight = []
speed = []
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))

idata = {'Age':age,'Height':height,'Weight':weight,'Speed':speed}

# %%
idata
# Out:
# {'Age': [56,
#   28,
#   68,
#   46,
#   94,
#   75,
#   35,
#   78,
#   71,
#   6,
#   3,
#   61,
#   32,
#   9,
#   28,
#   25,
#   73,
#   47,
#   55,
#   57,
#   88,
#   15,
#   40,
#   98,
#   76,
#   11,
#   18,
#   11,
#   26,
#   15,
#   9,
#   25,
#   29,
#   98,
#   14,
#   76,
#   12,
#   72,
#   55,
#   32,
#   32,
#   15,
#   81,
#   21,
#   91,
#   56,
#   73,
#   86,
#   55,
#   52,
#   84,
#   11,
#   23,
#   50,
#   97,
#   17,
#   12,
#   98,
#   92,
#   97,
#   24,
#   56,
#   63,
#   52,
#   62,
#   69,
#   66,
#   90,
#   4,
#   55,
#   31,
#   53,
#   11,
#   32,
#   44,
#   100,
#   16,
#   7,
#   52,
#   9,
#   19,
#   44,
#   94,
#   98,
#   17,
#   94,
#   30,
#   12,
#   19,
#   24,
#   56,
#   76,
#   74,
#   2,
#   61,
#   40,
#   63,
#   89,
#   33,
#   29],
#  'Height': [95,
#   36,
#   67,
#   68,
#   60,
#   30,
#   53,
#   46,
#   100,
#   51,
#   100,
#   47,
#   7,
#   38,
#   31,
#   74,
#   28,
#   87,
#   80,
#   56,
#   92,
#   41,
#   20,
#   26,
#   20,
#   54,
#   72,
#   3,
#   62,
#   88,
#   56,
#   58,
#   95,
#   59,
#   25,
#   58,
#   16,
#   53,
#   37,
#   53,
#   43,
#   44,
#   54,
#   93,
#   52,
#   75,
#   51,
#   100,
#   90,
#   2,
#   13,
#   39,
#   70,
#   44,
#   30,
#   60,
#   39,
#   10,
#   49,
#   14,
#   62,
#   69,
#   80,
#   55,
#   88,
#   100,
#   12,
#   13,
#   86,
#   72,
#   39,
#   81,
#   58,
#   76,
#   64,
#   61,
#   36,
#   94,
#   51,
#   39,
#   21,
#   38,
#   2,
#   74,
#   51,
#   71,
#   9,
#   1,
#   52,
#   54,
#   67,
#   66,
#   89,
#   94,
#   29,
#   29,
#   77,
#   30,
#   6,
#   41],
#  'Weight': [24,
#   37,
#   91,
#   82,
#   89,
#   44,
#   25,
#   27,
#   66,
#   64,
#   16,
#   53,
#   62,
#   36,
#   56,
#   2,
#   92,
#   59,
#   54,
#   75,
#   19,
#   53,
#   10,
#   9,
#   62,
#   41,
#   28,
#   69,
#   64,
#   46,
#   78,
#   32,
#   81,
#   88,
#   23,
#   34,
#   30,
#   19,
#   64,
#   6,
#   97,
#   42,
#   63,
#   69,
#   20,
#   40,
#   25,
#   2,
#   82,
#   39,
#   67,
#   81,
#   25,
#   58,
#   49,
#   6,
#   16,
#   72,
#   41,
#   33,
#   97,
#   5,
#   42,
#   76,
#   33,
#   66,
#   39,
#   2,
#   56,
#   29,
#   19,
#   16,
#   92,
#   93,
#   19,
#   89,
#   78,
#   31,
#   82,
#   82,
#   35,
#   71,
#   89,
#   78,
#   64,
#   18,
#   48,
#   94,
#   79,
#   18,
#   13,
#   53,
#   97,
#   55,
#   5,
#   93,
#   82,
#   25,
#   61,
#   43],
#  'Speed': [81,
#   6,
#   90,
#   92,
#   77,
#   2,
#   19,
#   28,
#   79,
#   82,
#   93,
#   32,
#   7,
#   61,
#   63,
#   62,
#   28,
#   16,
#   14,
#   82,
#   100,
#   78,
#   66,
#   67,
#   15,
#   32,
#   17,
#   4,
#   86,
#   79,
#   0,
#   16,
#   26,
#   81,
#   78,
#   67,
#   46,
#   81,
#   1,
#   10,
#   47,
#   14,
#   100,
#   4,
#   85,
#   3,
#   86,
#   100,
#   57,
#   78,
#   37,
#   28,
#   21,
#   91,
#   18,
#   62,
#   27,
#   55,
#   10,
#   84,
#   8,
#   94,
#   35,
#   86,
#   13,
#   68,
#   97,
#   90,
#   79,
#   4,
#   40,
#   92,
#   77,
#   11,
#   29,
#   81,
#   60,
#   89,
#   63,
#   44,
#   25,
#   96,
#   18,
#   41,
#   11,
#   30,
#   45,
#   81,
#   91,
#   19,
#   14,
#   43,
#   81,
#   99,
#   96,
#   66,
#   21,
#   39,
#   80,
#   68]}

# %%
df1 = pd.DataFrame(idata)

# %%
df1
# Out:
#     Age  Height  Weight  Speed
# 0    56      95      24     81
# 1    28      36      37      6
# 2    68      67      91     90
# 3    46      68      82     92
# 4    94      60      89     77
# ..  ...     ...     ...    ...
# 95   40      29      93     66
# 96   63      77      82     21
# 97   89      30      25     39
# 98   33       6      61     80
# 99   29      41      43     68
#
# [100 rows x 4 columns]

# %%
df1.head(10)
# Out:
#    Age  Height  Weight  Speed
# 0   56      95      24     81
# 1   28      36      37      6
# 2   68      67      91     90
# 3   46      68      82     92
# 4   94      60      89     77
# 5   75      30      44      2
# 6   35      53      25     19
# 7   78      46      27     28
# 8   71     100      66     79
# 9    6      51      64     82

# %%
df1.tail(10)
# Out:
#     Age  Height  Weight  Speed
# 90   56      67      13     14
# 91   76      66      53     43
# 92   74      89      97     81
# 93    2      94      55     99
# 94   61      29       5     96
# 95   40      29      93     66
# 96   63      77      82     21
# 97   89      30      25     39
# 98   33       6      61     80
# 99   29      41      43     68

# %%
df1[['Age','Height']]
# Out:
#     Age  Height
# 0    56      95
# 1    28      36
# 2    68      67
# 3    46      68
# 4    94      60
# ..  ...     ...
# 95   40      29
# 96   63      77
# 97   89      30
# 98   33       6
# 99   29      41
#
# [100 rows x 2 columns]

# %%
df1.loc[[0,3],['Age','Height']]
# Out:
#    Age  Height
# 0   56      95
# 3   46      68

# %%
df2 = df1[['Age','Height']]

# %%
df2
# Out:
#     Age  Height
# 0    56      95
# 1    28      36
# 2    68      67
# 3    46      68
# 4    94      60
# ..  ...     ...
# 95   40      29
# 96   63      77
# 97   89      30
# 98   33       6
# 99   29      41
#
# [100 rows x 2 columns]

# %%
df2.describe()
# Out:
#               Age    Height
# count  100.000000  100.0000
# mean    47.800000   52.5100
# std     29.720244   26.8631
# min      2.000000    1.0000
# 25%     20.500000   34.7500
# 50%     48.500000   53.0000
# 75%     73.000000   72.0000
# max    100.000000  100.0000

# %%
df1.sort_index(ascending = True)
# Out:
#     Age  Height  Weight  Speed
# 0    56      95      24     81
# 1    28      36      37      6
# 2    68      67      91     90
# 3    46      68      82     92
# 4    94      60      89     77
# ..  ...     ...     ...    ...
# 95   40      29      93     66
# 96   63      77      82     21
# 97   89      30      25     39
# 98   33       6      61     80
# 99   29      41      43     68
#
# [100 rows x 4 columns]

# %%
df1[0::2].describe()
# Out:
#              Age      Height    Weight       Speed
# count  50.000000   50.000000  50.00000   50.000000
# mean   47.220000   51.720000  52.98000   49.140000
# std    28.086085   28.061914  28.10802   32.427004
# min     3.000000    2.000000   5.00000    0.000000
# 25%    23.250000   29.250000  25.00000   18.250000
# 50%    48.000000   52.000000  56.00000   45.500000
# 75%    70.250000   71.500000  78.75000   79.750000
# max    97.000000  100.000000  97.00000  100.000000

# %%
 # Filter
filter1 = df1['Weight'] > 50

# %%
df1[filter1]
# Out:
#     Age  Height  Weight  Speed
# 2    68      67      91     90
# 3    46      68      82     92
# 4    94      60      89     77
# 8    71     100      66     79
# 9     6      51      64     82
# 11   61      47      53     32
# 12   32       7      62      7
# 14   28      31      56     63
# 16   73      28      92     28
# 17   47      87      59     16
# 18   55      80      54     14
# 19   57      56      75     82
# 21   15      41      53     78
# 24   76      20      62     15
# 27   11       3      69      4
# 28   26      62      64     86
# 30    9      56      78      0
# 32   29      95      81     26
# 33   98      59      88     81
# 38   55      37      64      1
# 40   32      43      97     47
# 42   81      54      63    100
# 43   21      93      69      4
# 48   55      90      82     57
# 50   84      13      67     37
# 51   11      39      81     28
# 53   50      44      58     91
# 57   98      10      72     55
# 60   24      62      97      8
# 63   52      55      76     86
# 65   69     100      66     68
# 68    4      86      56     79
# 72   11      58      92     77
# 73   32      76      93     11
# 75  100      61      89     81
# 76   16      36      78     60
# 78   52      51      82     63
# 79    9      39      82     44
# 81   44      38      71     96
# 82   94       2      89     18
# 83   98      74      78     41
# 84   17      51      64     11
# 87   12       1      94     81
# 88   19      52      79     91
# 91   76      66      53     43
# 92   74      89      97     81
# 93    2      94      55     99
# 95   40      29      93     66
# 96   63      77      82     21
# 98   33       6      61     80

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  Speed
# 2    68      67      91     90
# 3    46      68      82     92
# 4    94      60      89     77
# 8    71     100      66     79
# 9     6      51      64     82
# 11   61      47      53     32
# 12   32       7      62      7
# 14   28      31      56     63
# 16   73      28      92     28
# 17   47      87      59     16
# 18   55      80      54     14
# 19   57      56      75     82
# 21   15      41      53     78
# 24   76      20      62     15
# 27   11       3      69      4
# 28   26      62      64     86
# 30    9      56      78      0
# 32   29      95      81     26
# 33   98      59      88     81
# 38   55      37      64      1
# 40   32      43      97     47
# 42   81      54      63    100
# 43   21      93      69      4
# 48   55      90      82     57
# 50   84      13      67     37
# 51   11      39      81     28
# 53   50      44      58     91
# 57   98      10      72     55
# 60   24      62      97      8
# 63   52      55      76     86
# 65   69     100      66     68
# 68    4      86      56     79
# 72   11      58      92     77
# 73   32      76      93     11
# 75  100      61      89     81
# 76   16      36      78     60
# 78   52      51      82     63
# 79    9      39      82     44
# 81   44      38      71     96
# 82   94       2      89     18
# 83   98      74      78     41
# 84   17      51      64     11
# 87   12       1      94     81
# 88   19      52      79     91
# 91   76      66      53     43
# 92   74      89      97     81
# 93    2      94      55     99
# 95   40      29      93     66
# 96   63      77      82     21
# 98   33       6      61     80

# %%
filter2 = df1['Age'] > 50

# %%
df1[filter1 | filter2]
# Out:
#     Age  Height  Weight  Speed
# 0    56      95      24     81
# 2    68      67      91     90
# 3    46      68      82     92
# 4    94      60      89     77
# 5    75      30      44      2
# ..  ...     ...     ...    ...
# 94   61      29       5     96
# 95   40      29      93     66
# 96   63      77      82     21
# 97   89      30      25     39
# 98   33       6      61     80
#
# [76 rows x 4 columns]

# %%
df1.loc[filter1 & filter2]
# Out:
#     Age  Height  Weight  Speed
# 2    68      67      91     90
# 4    94      60      89     77
# 8    71     100      66     79
# 11   61      47      53     32
# 16   73      28      92     28
# 18   55      80      54     14
# 19   57      56      75     82
# 24   76      20      62     15
# 33   98      59      88     81
# 38   55      37      64      1
# 42   81      54      63    100
# 48   55      90      82     57
# 50   84      13      67     37
# 57   98      10      72     55
# 63   52      55      76     86
# 65   69     100      66     68
# 75  100      61      89     81
# 78   52      51      82     63
# 82   94       2      89     18
# 83   98      74      78     41
# 91   76      66      53     43
# 92   74      89      97     81
# 96   63      77      82     21
